# %%
import pandas as pd
import numpy as np
import regex
import seaborn
# Out:
# C:\Users\Felix\AppData\Local\Temp\ipykernel_17992\3181863982.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
IV19to23 = pd.read_csv(r'C:\Users\Felix\Documents\Datasets_For_IV_Housing\Copy of IVTU HOUSING DATA (updated) - 2019-2023 Price Adjust for 2024.csv')
IV19to23.replace(r'^\s*$',np.nan,regex=True)
# Out:
#      YEAR  STREET #     STREET NAME  BEDROOM  BATHROOM  \
# 0    2019      6566       DEL PLAYA        0       1.0
# 1    2019      6566       DEL PLAYA        3       2.0
# 2    2019      6566       DEL PLAYA        3       2.0
# 3    2019      6712       DEL PLAYA        2       1.0
# 4    2019      6712       DEL PLAYA        2       1.0
# ..    ...       ...             ...      ...       ...
# 192  2023      6530         SEVILLE        4       2.0
# 193  2023       775  CAMINO DEL SUR        2       2.0
# 194  2023      6559    SABADO TARDE        2       1.0
# 195  2023      6521       DEL PLAYA        2       2.0
# 196  2023      6647          ABREGO        4       2.0
#
#     MONTHLY RENT ($) NORMALIZE SECURITY ($) NORMALIZED FURNISHED (Y/N)  \
# 0                     1,809.55                1,809.55               N
# 1                     5,247.70                5,247.70               N
# 2                     5,428.66                5,428.66               N
# ...

# %%
IV19to23["BEDROOM"] = IV19to23["BEDROOM"].replace(0,1)
IV19to23["MONTHLY RENT ($) NORMALIZE"].strip(',')
IV19to23["MONTHLY RENT ($) NORMALIZE"].astype(np.float16)
IV19to23["RENT/BED"] = IV19to23["MONTHLY RENT ($) NORMALIZE"]/IV19to23["BEDROOM"]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17992\1864096475.py in ?()
#       1 IV19to23["BEDROOM"] = IV19to23["BEDROOM"].replace(0,1)
# ----> 2 IV19to23["MONTHLY RENT ($) NORMALIZE"].strip(',')
#       3 IV19to23["MONTHLY RENT ($) NORMALIZE"].astype(np.float16)
#       4 IV19to23["RENT/BED"] = IV19to23["MONTHLY RENT ($) NORMALIZE"]/IV19to23["BEDROOM"]
#
# c:\Users\Felix\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6289             and name not in self._accessors
#    6290             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6291         ):
#    6292             return self[name]
# -> 6293         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'strip'

# %%
IV19to23.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YEAR                        197 non-null    int64
#  1   STREET #                    197 non-null    int64
#  2   STREET NAME                 197 non-null    object
#  3   BEDROOM                     197 non-null    int64
#  4   BATHROOM                    197 non-null    float64
#  5   MONTHLY RENT ($) NORMALIZE  197 non-null    object
#  6   SECURITY ($) NORMALIZED     192 non-null    object
#  7   FURNISHED (Y/N)             197 non-null    object
#  8   WATER (Y/N)                 167 non-null    object
#  9   TRASH (Y/N)                 167 non-null    object
#  10  UTILITIES INCL              163 non-null    object
#  11  LEASOR                      194 non-null    object
#  12  UNIT #                      197 non-null    object
# ...

# %%
seaborn.pairplot(IV2019to2023, hue = "YEAR", kind="hist", y_vars= ["MONTHLY RENT ($)"], x_vars=["YEAR", "BEDROOM", "BATHROOM"], dropna = True)

# %%
histplot()
